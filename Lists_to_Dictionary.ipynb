# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisurekar05-ship-it/Python-Assignment/blob/main/Lists_to_Dictionary.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
keys = ["name", "age", "city"]
values = ["Sakshi", 19, "Mumbai"]

my_dict = dict(zip(keys, values))

print(my_dict)
# Out:
# {'name': 'Sakshi', 'age': 19, 'city': 'Mumbai'}
