# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisurekar05-ship-it/Python-Assignment/blob/main/Second_Largest_Number.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
numbers = [10, 20, 4, 45, 99]

numbers.sort()

print("Second Largest Number:", numbers[-2])
# Out:
# Second Largest Number: 45
