# %% [markdown]
# <a href="https://colab.research.google.com/github/sakshisurekar05-ship-it/Python-Assignment/blob/main/OOPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#What is OOPS?
#OOPS (Object Oriented Programming System)

#OOPS is a programming concept based on objects and classes.
#It helps in organizing code and makes programs reusable and secure.

#Main Concepts of OOPS
#Class
#Object
#Inheritance
#Polymorphism
#Encapsulation
#Abstraction

#Difference Between Class and Object
#| Class                  | Object                 |
#| ---------------------- | ---------------------- |
#| Blueprint or template  | Real instance of class |
#| Logical entity         | Physical entity        |
#| Does not occupy memory | Occupies memory        |
#| Used to create objects | Created from class     |
